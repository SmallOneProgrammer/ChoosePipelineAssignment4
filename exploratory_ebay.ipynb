# %%
import pandas as pd
from exploratory import Explore
from exploratory import ExploreTrain

explore_ebay = Explore('data/ebay.csv')
df_explore, features_explore = explore_ebay.read_csv(index = True)

# %%
#check shape before and after dropping null values
print(df_explore.shape)

df_explore = explore_ebay.drop_na(df_explore)

print(df_explore.shape)
# Out:
# (1000, 8)
# (1000, 8)

# %%
df_explore.columns
# Out:
# Index(['item_category', 'item_condition', 'seller_rating', 'auction_duration',
#        'starting_price', 'number_of_bidders', 'buy_price', 'ship_price'],
#       dtype='object')

# %%
#ship price is the target, lets see the statistics of the target

df_explore.describe()
# Out:
#        seller_rating  auction_duration  starting_price  number_of_bidders  \
# count    1000.000000       1000.000000     1000.000000        1000.000000
# mean        3.005240         72.480000      512.031470          49.254000
# std         1.176053         33.630531      295.705893          28.407437
# min         1.000000         24.000000       11.320000           0.000000
# 25%         2.000000         48.000000      246.842500          25.000000
# 50%         3.000000         72.000000      500.695000          50.000000
# 75%         4.052500         96.000000      790.797500          73.000000
# max         4.990000        120.000000      998.670000         100.000000
#
#          buy_price   ship_price
# count  1000.000000  1000.000000
# mean   1790.384960    35.807699
# std    1342.817145    26.856343
# min      18.360000     0.367200
# 25%     697.700000    13.954000
# 50%    1433.560000    28.671200
# 75%    2671.375000    53.427500
# max    5806.070000   116.121400

# %%
#lets see the distribution of the features
ExploreTrain.check_distribution(df_explore, features_explore)
# Out:
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)

# %%
explore_ebay.display_chart(df_explore, features_explore, 'ship_price')
# Out:
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)

# %%
ExploreTrain.pycaret_explore(df_explore, 'ship_price', 'regression')
# Out:
# <style type="text/css">
# #T_06b27_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_06b27">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_06b27_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_06b27_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_06b27_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_06b27_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_06b27_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_06b27_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_06b27_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_06b27_row1_col1" class="data row1 col1" >ship_price</td>
#     </tr>
#     <tr>
#       <th id="T_06b27_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_06b27_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_06b27_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_06b27_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_06b27_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_06b27_row3_col1" class="data row3 col1" >(1000, 8)</td>
#     </tr>
#     <tr>
#       <th id="T_06b27_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_06b27_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_06b27_row4_col1" class="data row4 col1" >(1000, 14)</td>
#     </tr>
#     <tr>
#       <th id="T_06b27_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_06b27_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_06b27_row5_col1" class="data row5 col1" >(700, 14)</td>
#     </tr>
#     <tr>
#       <th id="T_06b27_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_06b27_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_06b27_row6_col1" class="data row6 col1" >(300, 14)</td>
#     </tr>
#     <tr>
#       <th id="T_06b27_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_06b27_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_06b27_row7_col1" class="data row7 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_06b27_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_06b27_row8_col0" class="data row8 col0" >Categorical features</td>
#       <td id="T_06b27_row8_col1" class="data row8 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_06b27_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_06b27_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_06b27_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_06b27_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_06b27_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_06b27_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_06b27_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_06b27_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_06b27_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_06b27_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_06b27_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_06b27_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_06b27_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_06b27_row13_col0" class="data row13 col0" >Maximum one-hot encoding</td>
#       <td id="T_06b27_row13_col1" class="data row13 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_06b27_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_06b27_row14_col0" class="data row14 col0" >Encoding method</td>
#       <td id="T_06b27_row14_col1" class="data row14 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_06b27_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_06b27_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_06b27_row15_col1" class="data row15 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_06b27_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_06b27_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_06b27_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_06b27_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_06b27_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_06b27_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_06b27_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_06b27_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_06b27_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_06b27_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_06b27_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_06b27_row19_col1" class="data row19 col1" >MlflowLogger</td>
#     </tr>
#     <tr>
#       <th id="T_06b27_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_06b27_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_06b27_row20_col1" class="data row20 col1" >ship_price</td>
#     </tr>
#     <tr>
#       <th id="T_06b27_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_06b27_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_06b27_row21_col1" class="data row21 col1" >4310</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_f27ba th {
#   text-align: left;
# }
# #T_f27ba_row0_col0, #T_f27ba_row1_col0, #T_f27ba_row1_col1, #T_f27ba_row1_col3, #T_f27ba_row1_col5, #T_f27ba_row1_col6, #T_f27ba_row2_col0, #T_f27ba_row3_col0, #T_f27ba_row3_col1, #T_f27ba_row3_col3, #T_f27ba_row3_col5, #T_f27ba_row4_col0, #T_f27ba_row5_col0, #T_f27ba_row6_col0, #T_f27ba_row6_col1, #T_f27ba_row6_col2, #T_f27ba_row6_col3, #T_f27ba_row6_col5, #T_f27ba_row6_col6, #T_f27ba_row7_col0, #T_f27ba_row8_col0, #T_f27ba_row8_col1, #T_f27ba_row8_col3, #T_f27ba_row8_col5, #T_f27ba_row8_col6, #T_f27ba_row9_col0, #T_f27ba_row10_col0, #T_f27ba_row10_col1, #T_f27ba_row10_col2, #T_f27ba_row10_col3, #T_f27ba_row10_col4, #T_f27ba_row10_col5, #T_f27ba_row10_col6, #T_f27ba_row11_col0, #T_f27ba_row11_col1, #T_f27ba_row11_col2, #T_f27ba_row11_col3, #T_f27ba_row11_col4, #T_f27ba_row11_col5, #T_f27ba_row11_col6, #T_f27ba_row12_col0, #T_f27ba_row12_col1, #T_f27ba_row12_col2, #T_f27ba_row12_col3, #T_f27ba_row12_col4, #T_f27ba_row12_col5, #T_f27ba_row12_col6, #T_f27ba_row13_col0, #T_f27ba_row13_col1, #T_f27ba_row13_col2, #T_f27ba_row13_col3, #T_f27ba_row13_col4, #T_f27ba_row13_col5, #T_f27ba_row13_col6, #T_f27ba_row14_col0, #T_f27ba_row14_col1, #T_f27ba_row14_col2, #T_f27ba_row14_col3, #T_f27ba_row14_col4, #T_f27ba_row14_col5, #T_f27ba_row14_col6, #T_f27ba_row15_col0, #T_f27ba_row15_col1, #T_f27ba_row15_col2, #T_f27ba_row15_col3, #T_f27ba_row15_col4, #T_f27ba_row15_col5, #T_f27ba_row15_col6, #T_f27ba_row16_col0, #T_f27ba_row16_col1, #T_f27ba_row16_col2, #T_f27ba_row16_col3, #T_f27ba_row16_col4, #T_f27ba_row16_col5, #T_f27ba_row16_col6, #T_f27ba_row17_col0, #T_f27ba_row17_col1, #T_f27ba_row17_col2, #T_f27ba_row17_col3, #T_f27ba_row17_col4, #T_f27ba_row17_col5, #T_f27ba_row17_col6 {
#   text-align: left;
# }
# #T_f27ba_row0_col1, #T_f27ba_row0_col2, #T_f27ba_row0_col3, #T_f27ba_row0_col4, #T_f27ba_row0_col5, #T_f27ba_row0_col6, #T_f27ba_row1_col2, #T_f27ba_row1_col4, #T_f27ba_row2_col1, #T_f27ba_row2_col2, #T_f27ba_row2_col3, #T_f27ba_row2_col4, #T_f27ba_row2_col5, #T_f27ba_row2_col6, #T_f27ba_row3_col2, #T_f27ba_row3_col4, #T_f27ba_row3_col6, #T_f27ba_row4_col1, #T_f27ba_row4_col2, #T_f27ba_row4_col3, #T_f27ba_row4_col4, #T_f27ba_row4_col5, #T_f27ba_row4_col6, #T_f27ba_row5_col1, #T_f27ba_row5_col2, #T_f27ba_row5_col3, #T_f27ba_row5_col4, #T_f27ba_row5_col5, #T_f27ba_row5_col6, #T_f27ba_row6_col4, #T_f27ba_row7_col1, #T_f27ba_row7_col2, #T_f27ba_row7_col3, #T_f27ba_row7_col4, #T_f27ba_row7_col5, #T_f27ba_row7_col6, #T_f27ba_row8_col2, #T_f27ba_row8_col4, #T_f27ba_row9_col1, #T_f27ba_row9_col2, #T_f27ba_row9_col3, #T_f27ba_row9_col4, #T_f27ba_row9_col5, #T_f27ba_row9_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_f27ba_row0_col7, #T_f27ba_row1_col7, #T_f27ba_row2_col7, #T_f27ba_row3_col7, #T_f27ba_row4_col7, #T_f27ba_row5_col7, #T_f27ba_row6_col7, #T_f27ba_row7_col7, #T_f27ba_row8_col7, #T_f27ba_row9_col7, #T_f27ba_row10_col7, #T_f27ba_row11_col7, #T_f27ba_row12_col7, #T_f27ba_row13_col7, #T_f27ba_row14_col7, #T_f27ba_row15_col7, #T_f27ba_row16_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_f27ba_row17_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_f27ba">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f27ba_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_f27ba_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_f27ba_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_f27ba_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_f27ba_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_f27ba_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_f27ba_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_f27ba_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f27ba_level0_row0" class="row_heading level0 row0" >lr</th>
#       <td id="T_f27ba_row0_col0" class="data row0 col0" >Linear Regression</td>
#       <td id="T_f27ba_row0_col1" class="data row0 col1" >0.0000</td>
#       <td id="T_f27ba_row0_col2" class="data row0 col2" >0.0000</td>
#       <td id="T_f27ba_row0_col3" class="data row0 col3" >0.0000</td>
#       <td id="T_f27ba_row0_col4" class="data row0 col4" >1.0000</td>
#       <td id="T_f27ba_row0_col5" class="data row0 col5" >0.0000</td>
#       <td id="T_f27ba_row0_col6" class="data row0 col6" >0.0000</td>
#       <td id="T_f27ba_row0_col7" class="data row0 col7" >0.0970</td>
#     </tr>
#     <tr>
#       <th id="T_f27ba_level0_row1" class="row_heading level0 row1" >llar</th>
#       <td id="T_f27ba_row1_col0" class="data row1 col0" >Lasso Least Angle Regression</td>
#       <td id="T_f27ba_row1_col1" class="data row1 col1" >0.0006</td>
#       <td id="T_f27ba_row1_col2" class="data row1 col2" >0.0000</td>
#       <td id="T_f27ba_row1_col3" class="data row1 col3" >0.0007</td>
#       <td id="T_f27ba_row1_col4" class="data row1 col4" >1.0000</td>
#       <td id="T_f27ba_row1_col5" class="data row1 col5" >0.0001</td>
#       <td id="T_f27ba_row1_col6" class="data row1 col6" >0.0001</td>
#       <td id="T_f27ba_row1_col7" class="data row1 col7" >0.0780</td>
#     </tr>
#     <tr>
#       <th id="T_f27ba_level0_row2" class="row_heading level0 row2" >omp</th>
#       <td id="T_f27ba_row2_col0" class="data row2 col0" >Orthogonal Matching Pursuit</td>
#       <td id="T_f27ba_row2_col1" class="data row2 col1" >0.0000</td>
#       <td id="T_f27ba_row2_col2" class="data row2 col2" >0.0000</td>
#       <td id="T_f27ba_row2_col3" class="data row2 col3" >0.0000</td>
#       <td id="T_f27ba_row2_col4" class="data row2 col4" >1.0000</td>
#       <td id="T_f27ba_row2_col5" class="data row2 col5" >0.0000</td>
#       <td id="T_f27ba_row2_col6" class="data row2 col6" >0.0000</td>
#       <td id="T_f27ba_row2_col7" class="data row2 col7" >0.1070</td>
#     </tr>
#     <tr>
#       <th id="T_f27ba_level0_row3" class="row_heading level0 row3" >en</th>
#       <td id="T_f27ba_row3_col0" class="data row3 col0" >Elastic Net</td>
#       <td id="T_f27ba_row3_col1" class="data row3 col1" >0.0003</td>
#       <td id="T_f27ba_row3_col2" class="data row3 col2" >0.0000</td>
#       <td id="T_f27ba_row3_col3" class="data row3 col3" >0.0004</td>
#       <td id="T_f27ba_row3_col4" class="data row3 col4" >1.0000</td>
#       <td id="T_f27ba_row3_col5" class="data row3 col5" >0.0001</td>
#       <td id="T_f27ba_row3_col6" class="data row3 col6" >0.0000</td>
#       <td id="T_f27ba_row3_col7" class="data row3 col7" >0.1100</td>
#     </tr>
#     <tr>
#       <th id="T_f27ba_level0_row4" class="row_heading level0 row4" >lar</th>
#       <td id="T_f27ba_row4_col0" class="data row4 col0" >Least Angle Regression</td>
#       <td id="T_f27ba_row4_col1" class="data row4 col1" >0.0000</td>
#       <td id="T_f27ba_row4_col2" class="data row4 col2" >0.0000</td>
#       <td id="T_f27ba_row4_col3" class="data row4 col3" >0.0000</td>
#       <td id="T_f27ba_row4_col4" class="data row4 col4" >1.0000</td>
#       <td id="T_f27ba_row4_col5" class="data row4 col5" >0.0000</td>
#       <td id="T_f27ba_row4_col6" class="data row4 col6" >0.0000</td>
#       <td id="T_f27ba_row4_col7" class="data row4 col7" >0.0760</td>
#     </tr>
#     <tr>
#       <th id="T_f27ba_level0_row5" class="row_heading level0 row5" >ridge</th>
#       <td id="T_f27ba_row5_col0" class="data row5 col0" >Ridge Regression</td>
#       <td id="T_f27ba_row5_col1" class="data row5 col1" >0.0000</td>
#       <td id="T_f27ba_row5_col2" class="data row5 col2" >0.0000</td>
#       <td id="T_f27ba_row5_col3" class="data row5 col3" >0.0000</td>
#       <td id="T_f27ba_row5_col4" class="data row5 col4" >1.0000</td>
#       <td id="T_f27ba_row5_col5" class="data row5 col5" >0.0000</td>
#       <td id="T_f27ba_row5_col6" class="data row5 col6" >0.0000</td>
#       <td id="T_f27ba_row5_col7" class="data row5 col7" >0.0860</td>
#     </tr>
#     <tr>
#       <th id="T_f27ba_level0_row6" class="row_heading
# <style type="text/css">
# #T_c3a18_row10_col0, #T_c3a18_row10_col1, #T_c3a18_row10_col2, #T_c3a18_row10_col3, #T_c3a18_row10_col4, #T_c3a18_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_c3a18">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c3a18_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_c3a18_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_c3a18_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_c3a18_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_c3a18_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_c3a18_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c3a18_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c3a18_row0_col0" class="data row0 col0" >0.0000</td>
#       <td id="T_c3a18_row0_col1" class="data row0 col1" >0.0000</td>
#       <td id="T_c3a18_row0_col2" class="data row0 col2" >0.0000</td>
#       <td id="T_c3a18_row0_col3" class="data row0 col3" >1.0000</td>
#       <td id="T_c3a18_row0_col4" class="data row0 col4" >0.0000</td>
#       <td id="T_c3a18_row0_col5" class="data row0 col5" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_c3a18_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c3a18_row1_col0" class="data row1 col0" >0.0000</td>
#       <td id="T_c3a18_row1_col1" class="data row1 col1" >0.0000</td>
#       <td id="T_c3a18_row1_col2" class="data row1 col2" >0.0000</td>
#       <td id="T_c3a18_row1_col3" class="data row1 col3" >1.0000</td>
#       <td id="T_c3a18_row1_col4" class="data row1 col4" >0.0000</td>
#       <td id="T_c3a18_row1_col5" class="data row1 col5" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_c3a18_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c3a18_row2_col0" class="data row2 col0" >0.0000</td>
#       <td id="T_c3a18_row2_col1" class="data row2 col1" >0.0000</td>
#       <td id="T_c3a18_row2_col2" class="data row2 col2" >0.0000</td>
#       <td id="T_c3a18_row2_col3" class="data row2 col3" >1.0000</td>
#       <td id="T_c3a18_row2_col4" class="data row2 col4" >0.0000</td>
#       <td id="T_c3a18_row2_col5" class="data row2 col5" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_c3a18_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c3a18_row3_col0" class="data row3 col0" >0.0000</td>
#       <td id="T_c3a18_row3_col1" class="data row3 col1" >0.0000</td>
#       <td id="T_c3a18_row3_col2" class="data row3 col2" >0.0000</td>
#       <td id="T_c3a18_row3_col3" class="data row3 col3" >1.0000</td>
#       <td id="T_c3a18_row3_col4" class="data row3 col4" >0.0000</td>
#       <td id="T_c3a18_row3_col5" class="data row3 col5" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_c3a18_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c3a18_row4_col0" class="data row4 col0" >0.0000</td>
#       <td id="T_c3a18_row4_col1" class="data row4 col1" >0.0000</td>
#       <td id="T_c3a18_row4_col2" class="data row4 col2" >0.0000</td>
#       <td id="T_c3a18_row4_col3" class="data row4 col3" >1.0000</td>
#       <td id="T_c3a18_row4_col4" class="data row4 col4" >0.0000</td>
#       <td id="T_c3a18_row4_col5" class="data row4 col5" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_c3a18_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_c3a18_row5_col0" class="data row5 col0" >0.0000</td>
#       <td id="T_c3a18_row5_col1" class="data row5 col1" >0.0000</td>
#       <td id="T_c3a18_row5_col2" class="data row5 col2" >0.0000</td>
#       <td id="T_c3a18_row5_col3" class="data row5 col3" >1.0000</td>
#       <td id="T_c3a18_row5_col4" class="data row5 col4" >0.0000</td>
#       <td id="T_c3a18_row5_col5" class="data row5 col5" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_c3a18_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_c3a18_row6_col0" class="data row6 col0" >0.0000</td>
#       <td id="T_c3a18_row6_col1" class="data row6 col1" >0.0000</td>
#       <td id="T_c3a18_row6_col2" class="data row6 col2" >0.0000</td>
#       <td id="T_c3a18_row6_col3" class="data row6 col3" >1.0000</td>
#       <td id="T_c3a18_row6_col4" class="data row6 col4" >0.0000</td>
#       <td id="T_c3a18_row6_col5" class="data row6 col5" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_c3a18_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_c3a18_row7_col0" class="data row7 col0" >0.0000</td>
#       <td id="T_c3a18_row7_col1" class="data row7 col1" >0.0000</td>
#       <td id="T_c3a18_row7_col2" class="data row7 col2" >0.0000</td>
#       <td id="T_c3a18_row7_col3" class="data row7 col3" >1.0000</td>
#       <td id="T_c3a18_row7_col4" class="data row7 col4" >0.0000</td>
#       <td id="T_c3a18_row7_col5" class="data row7 col5" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_c3a18_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_c3a18_row8_col0" class="data row8 col0" >0.0000</td>
#       <td id="T_c3a18_row8_col1" class="data row8 col1" >0.0000</td>
#       <td id="T_c3a18_row8_col2" class="data row8 col2" >0.0000</td>
#       <td id="T_c3a18_row8_col3" class="data row8 col3" >1.0000</td>
#       <td id="T_c3a18_row8_col4" class="data row8 col4" >0.0000</td>
#       <td id="T_c3a18_row8_col5" class="data row8 col5" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_c3a18_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_c3a18_row9_col0" class="data row9 col0" >0.0000</td>
#       <td id="T_c3a18_row9_col1" class="data row9 col1" >0.0000</td>
#       <td id="T_c3a18_row9_col2" class="data row9 col2" >0.0000</td>
#       <td id="T_c3a18_row9_col3" class="data row9 col3" >1.0000</td>
#       <td id="T_c3a18_row9_col4" class="data row9 col4" >0.0000</td>
#       <td id="T_c3a18_row9_col5" class="data row9 col5" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_c3a18_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_c3a18_row10_col0" class="data row10 col0" >0.0000</td>
#       <td id="T_c3a18_row10_col1" class="data row10 col1" >0.0000</td>
#       <td id="T_c3a18_row10_col2" class="data row10 col2" >0.0000</td>
#       <td id="T_c3a18_row10_col3" class="data row10 col3" >1.0000</td>
#       <td id="T_c3a18_row10_col4" class="data row10 col4" >0.0000</td>
#       <td id="T_c3a18_row10_col5" class="data row10 col5" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_c3a18_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_c3a18_row11_col0" class="data row11 col0" >0.0000</td>
#       <td id="T_c3a18_row11_col1" class="data row11 col1" >0.0000</td>
#       <td id="T_c3a18_row11_col2" class="data row11 col2" >0.0000</td>
#       <td id="T_c3a18_row11_col3" class="data row11 col3" >0.0000</td>
#       <td id="T_c3a18_row11_col4" class="data row11 col4" >0.0000</td>
#       <td id="T_c3a18_row11_col5" class="data row11 col5" >0.0000</td>
#     </tr>
#   </tbody>
# </table>
# Fitting 10 folds for each of 2 candidates, totalling 20 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
#clearly there is something fishy going on with 1.00 R2 score, there must be leakage in the data

#lets think of DAGS to see what the leakage could be
#seller_rating -> item_condition -> num_of_bidders -> buy_price -> ship_price
#seller_rating -> auction_duration -> num_of_bidders -> buyout_price -> ship_price
#seller_rating -> starting_price -> num_of_bidders -> buyout_price -> ship_price
#seller_rating -> starting_price -> auction_duration -> num_of_bidders -> buyout_price -> ship_price
#item_condition -> starting_price -> auction_duration -> num_of_bidders -> buyout_price -> ship_price
#item_category -> starting_price -> auction_duration -> num_of_bidders -> buyout_price -> ship_price
#item_condition -> auction_duration -> num_of_bidders -> buyout_price -> ship_price
#item_category -> auction_duration -> num_of_bidders -> buyout_price -> ship_price
#clearly there are a large number of colliders in the data which are causing leakage.
#The one feature that is not causing leakage is the seller_rating, so we will drop all the other features

df_explore = explore_ebay.drop_columns(df_explore,
    columns = ['item_condition', 'item_category', 'number_of_bidders',
    'auction_duration', 'buy_price', 'starting_price'])

# %%
print(df_explore)
try: 
    ExploreTrain.pycaret_explore(df_explore, 'ship_price', 'regression')
except:
    raise Exception('There is an issue with the regression or the evaluation of the regression model')
# Out:
#     item_category item_condition  seller_rating  ship_price
# 0             Art            New           2.66     27.0560
# 1     Electronics    Refurbished           4.69     61.7168
# 2     Electronics            New           1.35     95.8554
# 3         Fashion    Refurbished           2.71     62.6490
# 4        Antiques            New           4.14     36.9570
# ..            ...            ...            ...         ...
# 995      Antiques            New           4.91     54.9430
# 996       Fashion    Refurbished           3.92     49.4106
# 997   Electronics            New           2.07     34.0174
# 998           Art           Used           2.73     11.0420
# 999      Antiques            New           4.81     67.4158
#
# [1000 rows x 4 columns]
# <style type="text/css">
# #T_0cc4c_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_0cc4c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0cc4c_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_0cc4c_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0cc4c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0cc4c_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_0cc4c_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_0cc4c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0cc4c_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_0cc4c_row1_col1" class="data row1 col1" >ship_price</td>
#     </tr>
#     <tr>
#       <th id="T_0cc4c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0cc4c_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_0cc4c_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_0cc4c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_0cc4c_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_0cc4c_row3_col1" class="data row3 col1" >(1000, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_0cc4c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_0cc4c_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_0cc4c_row4_col1" class="data row4 col1" >(1000, 10)</td>
#     </tr>
#     <tr>
#       <th id="T_0cc4c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_0cc4c_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_0cc4c_row5_col1" class="data row5 col1" >(700, 10)</td>
#     </tr>
#     <tr>
#       <th id="T_0cc4c_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_0cc4c_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_0cc4c_row6_col1" class="data row6 col1" >(300, 10)</td>
#     </tr>
#     <tr>
#       <th id="T_0cc4c_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_0cc4c_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_0cc4c_row7_col1" class="data row7 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_0cc4c_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_0cc4c_row8_col0" class="data row8 col0" >Categorical features</td>
#       <td id="T_0cc4c_row8_col1" class="data row8 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_0cc4c_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_0cc4c_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_0cc4c_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_0cc4c_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_0cc4c_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_0cc4c_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_0cc4c_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_0cc4c_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_0cc4c_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_0cc4c_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_0cc4c_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_0cc4c_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_0cc4c_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_0cc4c_row13_col0" class="data row13 col0" >Maximum one-hot encoding</td>
#       <td id="T_0cc4c_row13_col1" class="data row13 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_0cc4c_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_0cc4c_row14_col0" class="data row14 col0" >Encoding method</td>
#       <td id="T_0cc4c_row14_col1" class="data row14 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_0cc4c_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_0cc4c_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_0cc4c_row15_col1" class="data row15 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_0cc4c_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_0cc4c_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_0cc4c_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_0cc4c_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_0cc4c_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_0cc4c_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_0cc4c_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_0cc4c_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_0cc4c_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_0cc4c_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_0cc4c_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_0cc4c_row19_col1" class="data row19 col1" >MlflowLogger</td>
#     </tr>
#     <tr>
#       <th id="T_0cc4c_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_0cc4c_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_0cc4c_row20_col1" class="data row20 col1" >ship_price</td>
#     </tr>
#     <tr>
#       <th id="T_0cc4c_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_0cc4c_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_0cc4c_row21_col1" class="data row21 col1" >f7ee</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_d47e0 th {
#   text-align: left;
# }
# #T_d47e0_row0_col0, #T_d47e0_row0_col1, #T_d47e0_row0_col5, #T_d47e0_row0_col6, #T_d47e0_row1_col0, #T_d47e0_row1_col1, #T_d47e0_row1_col2, #T_d47e0_row1_col3, #T_d47e0_row1_col4, #T_d47e0_row1_col5, #T_d47e0_row1_col6, #T_d47e0_row2_col0, #T_d47e0_row2_col1, #T_d47e0_row2_col2, #T_d47e0_row2_col3, #T_d47e0_row2_col4, #T_d47e0_row2_col5, #T_d47e0_row2_col6, #T_d47e0_row3_col0, #T_d47e0_row3_col1, #T_d47e0_row3_col2, #T_d47e0_row3_col3, #T_d47e0_row3_col4, #T_d47e0_row3_col5, #T_d47e0_row3_col6, #T_d47e0_row4_col0, #T_d47e0_row4_col1, #T_d47e0_row4_col2, #T_d47e0_row4_col3, #T_d47e0_row4_col4, #T_d47e0_row4_col5, #T_d47e0_row4_col6, #T_d47e0_row5_col0, #T_d47e0_row5_col1, #T_d47e0_row5_col2, #T_d47e0_row5_col3, #T_d47e0_row5_col4, #T_d47e0_row5_col5, #T_d47e0_row5_col6, #T_d47e0_row6_col0, #T_d47e0_row6_col1, #T_d47e0_row6_col2, #T_d47e0_row6_col3, #T_d47e0_row6_col4, #T_d47e0_row6_col5, #T_d47e0_row6_col6, #T_d47e0_row7_col0, #T_d47e0_row7_col1, #T_d47e0_row7_col2, #T_d47e0_row7_col3, #T_d47e0_row7_col4, #T_d47e0_row7_col5, #T_d47e0_row7_col6, #T_d47e0_row8_col0, #T_d47e0_row8_col1, #T_d47e0_row8_col2, #T_d47e0_row8_col3, #T_d47e0_row8_col4, #T_d47e0_row8_col5, #T_d47e0_row8_col6, #T_d47e0_row9_col0, #T_d47e0_row9_col2, #T_d47e0_row9_col3, #T_d47e0_row9_col4, #T_d47e0_row10_col0, #T_d47e0_row10_col1, #T_d47e0_row10_col2, #T_d47e0_row10_col3, #T_d47e0_row10_col4, #T_d47e0_row10_col5, #T_d47e0_row10_col6, #T_d47e0_row11_col0, #T_d47e0_row11_col1, #T_d47e0_row11_col2, #T_d47e0_row11_col3, #T_d47e0_row11_col4, #T_d47e0_row11_col5, #T_d47e0_row11_col6, #T_d47e0_row12_col0, #T_d47e0_row12_col1, #T_d47e0_row12_col2, #T_d47e0_row12_col3, #T_d47e0_row12_col4, #T_d47e0_row12_col5, #T_d47e0_row12_col6, #T_d47e0_row13_col0, #T_d47e0_row13_col1, #T_d47e0_row13_col2, #T_d47e0_row13_col3, #T_d47e0_row13_col4, #T_d47e0_row13_col5, #T_d47e0_row13_col6, #T_d47e0_row14_col0, #T_d47e0_row14_col1, #T_d47e0_row14_col2, #T_d47e0_row14_col3, #T_d47e0_row14_col4, #T_d47e0_row14_col5, #T_d47e0_row14_col6, #T_d47e0_row15_col0, #T_d47e0_row15_col1, #T_d47e0_row15_col2, #T_d47e0_row15_col3, #T_d47e0_row15_col4, #T_d47e0_row15_col5, #T_d47e0_row15_col6, #T_d47e0_row16_col0, #T_d47e0_row16_col1, #T_d47e0_row16_col2, #T_d47e0_row16_col3, #T_d47e0_row16_col4, #T_d47e0_row16_col5, #T_d47e0_row16_col6, #T_d47e0_row17_col0, #T_d47e0_row17_col1, #T_d47e0_row17_col2, #T_d47e0_row17_col3, #T_d47e0_row17_col4, #T_d47e0_row17_col5, #T_d47e0_row17_col6 {
#   text-align: left;
# }
# #T_d47e0_row0_col2, #T_d47e0_row0_col3, #T_d47e0_row0_col4, #T_d47e0_row9_col1, #T_d47e0_row9_col5, #T_d47e0_row9_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_d47e0_row0_col7, #T_d47e0_row1_col7, #T_d47e0_row3_col7, #T_d47e0_row4_col7, #T_d47e0_row5_col7, #T_d47e0_row6_col7, #T_d47e0_row7_col7, #T_d47e0_row8_col7, #T_d47e0_row9_col7, #T_d47e0_row10_col7, #T_d47e0_row11_col7, #T_d47e0_row12_col7, #T_d47e0_row13_col7, #T_d47e0_row14_col7, #T_d47e0_row15_col7, #T_d47e0_row16_col7, #T_d47e0_row17_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_d47e0_row2_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_d47e0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d47e0_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_d47e0_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_d47e0_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_d47e0_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_d47e0_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_d47e0_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_d47e0_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_d47e0_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d47e0_level0_row0" class="row_heading level0 row0" >dummy</th>
#       <td id="T_d47e0_row0_col0" class="data row0 col0" >Dummy Regressor</td>
#       <td id="T_d47e0_row0_col1" class="data row0 col1" >22.4250</td>
#       <td id="T_d47e0_row0_col2" class="data row0 col2" >738.9958</td>
#       <td id="T_d47e0_row0_col3" class="data row0 col3" >27.0873</td>
#       <td id="T_d47e0_row0_col4" class="data row0 col4" >-0.0389</td>
#       <td id="T_d47e0_row0_col5" class="data row0 col5" >0.9995</td>
#       <td id="T_d47e0_row0_col6" class="data row0 col6" >2.5625</td>
#       <td id="T_d47e0_row0_col7" class="data row0 col7" >0.1250</td>
#     </tr>
#     <tr>
#       <th id="T_d47e0_level0_row1" class="row_heading level0 row1" >omp</th>
#       <td id="T_d47e0_row1_col0" class="data row1 col0" >Orthogonal Matching Pursuit</td>
#       <td id="T_d47e0_row1_col1" class="data row1 col1" >22.4288</td>
#       <td id="T_d47e0_row1_col2" class="data row1 col2" >740.2821</td>
#       <td id="T_d47e0_row1_col3" class="data row1 col3" >27.1093</td>
#       <td id="T_d47e0_row1_col4" class="data row1 col4" >-0.0405</td>
#       <td id="T_d47e0_row1_col5" class="data row1 col5" >0.9996</td>
#       <td id="T_d47e0_row1_col6" class="data row1 col6" >2.5638</td>
#       <td id="T_d47e0_row1_col7" class="data row1 col7" >0.0940</td>
#     </tr>
#     <tr>
#       <th id="T_d47e0_level0_row2" class="row_heading level0 row2" >en</th>
#       <td id="T_d47e0_row2_col0" class="data row2 col0" >Elastic Net</td>
#       <td id="T_d47e0_row2_col1" class="data row2 col1" >22.4212</td>
#       <td id="T_d47e0_row2_col2" class="data row2 col2" >740.1583</td>
#       <td id="T_d47e0_row2_col3" class="data row2 col3" >27.1085</td>
#       <td id="T_d47e0_row2_col4" class="data row2 col4" >-0.0405</td>
#       <td id="T_d47e0_row2_col5" class="data row2 col5" >0.9997</td>
#       <td id="T_d47e0_row2_col6" class="data row2 col6" >2.5648</td>
#       <td id="T_d47e0_row2_col7" class="data row2 col7" >0.0670</td>
#     </tr>
#     <tr>
#       <th id="T_d47e0_level0_row3" class="row_heading level0 row3" >llar</th>
#       <td id="T_d47e0_row3_col0" class="data row3 col0" >Lasso Least Angle Regression</td>
#       <td id="T_d47e0_row3_col1" class="data row3 col1" >22.4441</td>
#       <td id="T_d47e0_row3_col2" class="data row3 col2" >740.8019</td>
#       <td id="T_d47e0_row3_col3" class="data row3 col3" >27.1208</td>
#       <td id="T_d47e0_row3_col4" class="data row3 col4" >-0.0415</td>
#       <td id="T_d47e0_row3_col5" class="data row3 col5" >1.0000</td>
#       <td id="T_d47e0_row3_col6" class="data row3 col6" >2.5644</td>
#       <td id="T_d47e0_row3_col7" class="data row3 col7" >0.1070</td>
#     </tr>
#     <tr>
#       <th id="T_d47e0_level0_row4" class="row_heading level0 row4" >lasso</th>
#       <td id="T_d47e0_row4_col0" class="data row4 col0" >Lasso Regression</td>
#       <td id="T_d47e0_row4_col1" class="data row4 col1" >22.4441</td>
#       <td id="T_d47e0_row4_col2" class="data row4 col2" >740.8020</td>
#       <td id="T_d47e0_row4_col3" class="data row4 col3" >27.1208</td>
#       <td id="T_d47e0_row4_col4" class="data row4 col4" >-0.0415</td>
#       <td id="T_d47e0_row4_col5" class="data row4 col5" >1.0000</td>
#       <td id="T_d47e0_row4_col6" class="data row4 col6" >2.5644</td>
#       <td id="T_d47e0_row4_col7" class="data row4 col7" >0.1190</td>
#     </tr>
#     <tr>
#       <th id="T_d47e0_level0_row5" class="row_heading level0 row5" >br</th>
#       <td id="T_d47e0_row5_col0" class="data row5 col0" >Bayesian Ridge</td>
#       <td id="T_d47e0_row5_col1" class="data row5 col1" >22.4530</td>
#       <td id="T_d47e0_row5_col2" class="data row5 col2" >743.6382</td>
#       <td id="T_d47e0_row5_col3" class="data row5 col3" >27.1735</td>
#       <td id="T_d47e0_row5_col4" class="data row5 col4" >-0.0456</td>
#       <td id="T_d47e0_row5_col5" class="data row5 col5" >1.0010</td>
#       <td id="T_d47e0_row5_col6" class="data row5 col6" >2.5678</td>
#       <td id="T_d47e0_row5_col7" class="data row5 col7" >0.0780</td>
#     </tr>
#     <tr>
#       <th id="T_d47e0_level0_ro
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                   18:17:01
# Status     . . . . . . . . . . . . . . . . . .  Searching Hyperparameters
# Estimator  . . . . . . . . . . . . . . . . . .            Dummy Regressor
# Processing:   0%|          | 0/7 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[62], line 3
#       2 try:
# ----> 3     ExploreTrain.pycaret_explore(df_explore, 'ship_price', 'regression')
#       4 except:
#
# File /Volumes/Untitled/Wolverine_Michigan/SIADS643MachineLearningPipelines/Assignment4/exploratory.py:101, in ExploreTrain.pycaret_explore(df, target, type_model)
#     100 #tune model
# --> 101 tuned_best = tune_model2(best)
#     102 #evaluate model
#
# File /Volumes/Untitled/Wolverine_Michigan/SIADS643MachineLearningPipelines/Assignment4/.venv/lib/python3.10/site-packages/pycaret/utils/generic.py:964, in check_if_global_is_not_none.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     963         raise ValueError(message)
# --> 964 return func(*args, **kwargs)
#
# File /Volumes/Untitled/Wolverine_Michigan/SIADS643MachineLearningPipelines/Assignment4/.venv/lib/python3.10/site-packages/pycaret/regression/functional.py:1197, in tune_model(estimator, fold, round, n_iter, custom_grid, optimize, custom_scorer, search_library, search_algorithm, early_stopping, early_stopping_max_iters, choose_better, fit_kwargs, groups, return_tuner, verbose, tuner_verbose, return_train_score, **kwargs)
#    1027 """
#    1028 This function tunes the hyperparameters of a given estimator. The output of
#    1029 this function is a score grid with CV scores by fold of the best selected
#    (...)
#    1194
#    1195 """
# -> 1197 return _CURRENT_EXPERIMENT.tune_model(
#    1198     estimator=estimator,
#    1199     fold=fold,
#    1200     round=round,
#    1201     n_iter=n_iter,
#    1202     custom_grid=custom_grid,
#    1203     optimize=optimize,
#    1204     custom_scorer=custom_scorer,
#    1205     search_library=search_library,
#    1206     search_algorithm=search_algorithm,
#    1207     early_stopping=early_stopping,
#    1208     early_stopping_max_iters=early_stopping_max_iters,
#    1209     choose_better=choose_better,
#    1210     fit_kwargs=fit_kwargs,
#    1211     groups=groups,
#    1212     return_tuner=return_tuner,
#    1213     verbose=verbose,
#    1214     tuner_verbose=tuner_verbose,
#    1215     return_train_score=return_train_score,
#    1216     **kwargs,
#    1217 )
#
# File /Volumes/Untitled/Wolverine_Michigan/SIADS643MachineLearningPipelines/Assignment4/.venv/lib/python3.10/site-packages/pycaret/regression/oop.py:1499, in RegressionExperiment.tune_model(self, estimator, fold, round, n_iter, custom_grid, optimize, custom_scorer, search_library, search_algorithm, early_stopping, early_stopping_max_iters, choose_better, fit_kwargs, groups, return_tuner, verbose, tuner_verbose, return_train_score, **kwargs)
#    1329 """
#    1330 This function tunes the hyperparameters of a given estimator. The output of
#    1331 this function is a score grid with CV scores by fold of the best selected
#    (...)
#    1496
#    1497 """
# -> 1499 return super().tune_model(
#    1500     estimator=estimator,
#    1501     fold=fold,
#    1502     round=round,
#    1503     n_iter=n_iter,
#    1504     custom_grid=custom_grid,
#    1505     optimize=optimize,
#    1506     custom_scorer=custom_scorer,
#    1507     search_library=search_library,
#    1508     search_algorithm=search_algorithm,
#    1509     early_stopping=early_stopping,
#    1510     early_stopping_max_iters=early_stopping_max_iters,
#    1511     choose_better=choose_better,
#    1512     fit_kwargs=fit_kwargs,
#    1513     groups=groups,
#    1514     return_tuner=return_tuner,
#    1515     verbose=verbose,
#    1516     tuner_verbose=tuner_verbose,
#    1517     return_train_score=return_train_score,
#    1518     **kwargs,
#    1519 )
#
# File /Volumes/Untitled/Wolverine_Michigan/SIADS643MachineLearningPipelines/Assignment4/.venv/lib/python3.10/site-packages/pycaret/internal/pycaret_experiment/supervised_experiment.py:2363, in _SupervisedExperiment.tune_model(self, estimator, fold, round, n_iter, custom_grid, optimize, custom_scorer, search_library, search_algorithm, early_stopping, early_stopping_max_iters, choose_better, fit_kwargs, groups, return_tuner, verbose, tuner_verbose, return_train_score, **kwargs)
#    2362 if not param_grid:
# -> 2363     raise ValueError(
#    2364         "parameter grid for tuning is empty. If passing custom_grid, make sure that it is not empty. If not passing custom_grid, the passed estimator does not have a built-in tuning grid."
#    2365     )
#    2367 suffixes = []
#
# ValueError: parameter grid for tuning is empty. If passing custom_grid, make sure that it is not empty. If not passing custom_grid, the passed estimator does not have a built-in tuning grid.
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# Cell In[62], line 5
#       3     ExploreTrain.pycaret_explore(df_explore, 'ship_price', 'regression')
#       4 except:
# ----> 5     raise Exception('There is an issue with the regression')
#
# Exception: There is an issue with the regression

# %%
#there was an issue with evaluating the regression as seen by the dummy regressor being the best regressor
# being the best regressor so lets try a more specific model to see if we can gleam more insights
#we choose the huber model because it is robust to outliers and the data has outliers 
# and can deal with heteroscedacisty
#is a good idea to use this dataset for putting a regression model into a pipeline
ExploreTrain.use_specific_model_pycaret(df_explore, 'ship_price', 'huber', 'regression')
# Out:
# <style type="text/css">
# #T_84163_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_84163">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_84163_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_84163_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_84163_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_84163_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_84163_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_84163_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_84163_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_84163_row1_col1" class="data row1 col1" >ship_price</td>
#     </tr>
#     <tr>
#       <th id="T_84163_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_84163_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_84163_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_84163_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_84163_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_84163_row3_col1" class="data row3 col1" >(1000, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_84163_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_84163_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_84163_row4_col1" class="data row4 col1" >(1000, 10)</td>
#     </tr>
#     <tr>
#       <th id="T_84163_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_84163_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_84163_row5_col1" class="data row5 col1" >(700, 10)</td>
#     </tr>
#     <tr>
#       <th id="T_84163_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_84163_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_84163_row6_col1" class="data row6 col1" >(300, 10)</td>
#     </tr>
#     <tr>
#       <th id="T_84163_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_84163_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_84163_row7_col1" class="data row7 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_84163_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_84163_row8_col0" class="data row8 col0" >Categorical features</td>
#       <td id="T_84163_row8_col1" class="data row8 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_84163_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_84163_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_84163_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_84163_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_84163_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_84163_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_84163_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_84163_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_84163_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_84163_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_84163_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_84163_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_84163_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_84163_row13_col0" class="data row13 col0" >Maximum one-hot encoding</td>
#       <td id="T_84163_row13_col1" class="data row13 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_84163_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_84163_row14_col0" class="data row14 col0" >Encoding method</td>
#       <td id="T_84163_row14_col1" class="data row14 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_84163_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_84163_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_84163_row15_col1" class="data row15 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_84163_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_84163_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_84163_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_84163_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_84163_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_84163_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_84163_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_84163_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_84163_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_84163_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_84163_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_84163_row19_col1" class="data row19 col1" >MlflowLogger</td>
#     </tr>
#     <tr>
#       <th id="T_84163_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_84163_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_84163_row20_col1" class="data row20 col1" >ship_price</td>
#     </tr>
#     <tr>
#       <th id="T_84163_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_84163_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_84163_row21_col1" class="data row21 col1" >51bb</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_12961_row10_col0, #T_12961_row10_col1, #T_12961_row10_col2, #T_12961_row10_col3, #T_12961_row10_col4, #T_12961_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_12961">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_12961_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_12961_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_12961_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_12961_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_12961_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_12961_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_12961_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_12961_row0_col0" class="data row0 col0" >18.5530</td>
#       <td id="T_12961_row0_col1" class="data row0 col1" >533.5129</td>
#       <td id="T_12961_row0_col2" class="data row0 col2" >23.0979</td>
#       <td id="T_12961_row0_col3" class="data row0 col3" >-0.0355</td>
#       <td id="T_12961_row0_col4" class="data row0 col4" >0.8921</td>
#       <td id="T_12961_row0_col5" class="data row0 col5" >1.5834</td>
#     </tr>
#     <tr>
#       <th id="T_12961_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_12961_row1_col0" class="data row1 col0" >19.2024</td>
#       <td id="T_12961_row1_col1" class="data row1 col1" >630.9410</td>
#       <td id="T_12961_row1_col2" class="data row1 col2" >25.1185</td>
#       <td id="T_12961_row1_col3" class="data row1 col3" >0.0491</td>
#       <td id="T_12961_row1_col4" class="data row1 col4" >0.8219</td>
#       <td id="T_12961_row1_col5" class="data row1 col5" >1.4989</td>
#     </tr>
#     <tr>
#       <th id="T_12961_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_12961_row2_col0" class="data row2 col0" >20.5550</td>
#       <td id="T_12961_row2_col1" class="data row2 col1" >637.5374</td>
#       <td id="T_12961_row2_col2" class="data row2 col2" >25.2495</td>
#       <td id="T_12961_row2_col3" class="data row2 col3" >-0.0418</td>
#       <td id="T_12961_row2_col4" class="data row2 col4" >0.9755</td>
#       <td id="T_12961_row2_col5" class="data row2 col5" >2.2444</td>
#     </tr>
#     <tr>
#       <th id="T_12961_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_12961_row3_col0" class="data row3 col0" >24.4580</td>
#       <td id="T_12961_row3_col1" class="data row3 col1" >945.9608</td>
#       <td id="T_12961_row3_col2" class="data row3 col2" >30.7565</td>
#       <td id="T_12961_row3_col3" class="data row3 col3" >-0.1471</td>
#       <td id="T_12961_row3_col4" class="data row3 col4" >1.0743</td>
#       <td id="T_12961_row3_col5" class="data row3 col5" >3.6022</td>
#     </tr>
#     <tr>
#       <th id="T_12961_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_12961_row4_col0" class="data row4 col0" >24.3775</td>
#       <td id="T_12961_row4_col1" class="data row4 col1" >995.6754</td>
#       <td id="T_12961_row4_col2" class="data row4 col2" >31.5543</td>
#       <td id="T_12961_row4_col3" class="data row4 col3" >-0.0943</td>
#       <td id="T_12961_row4_col4" class="data row4 col4" >0.9749</td>
#       <td id="T_12961_row4_col5" class="data row4 col5" >1.7309</td>
#     </tr>
#     <tr>
#       <th id="T_12961_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_12961_row5_col0" class="data row5 col0" >21.2002</td>
#       <td id="T_12961_row5_col1" class="data row5 col1" >632.7666</td>
#       <td id="T_12961_row5_col2" class="data row5 col2" >25.1549</td>
#       <td id="T_12961_row5_col3" class="data row5 col3" >0.0297</td>
#       <td id="T_12961_row5_col4" class="data row5 col4" >1.0648</td>
#       <td id="T_12961_row5_col5" class="data row5 col5" >2.9356</td>
#     </tr>
#     <tr>
#       <th id="T_12961_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_12961_row6_col0" class="data row6 col0" >23.3783</td>
#       <td id="T_12961_row6_col1" class="data row6 col1" >846.7444</td>
#       <td id="T_12961_row6_col2" class="data row6 col2" >29.0989</td>
#       <td id="T_12961_row6_col3" class="data row6 col3" >0.0210</td>
#       <td id="T_12961_row6_col4" class="data row6 col4" >1.1003</td>
#       <td id="T_12961_row6_col5" class="data row6 col5" >3.3312</td>
#     </tr>
#     <tr>
#       <th id="T_12961_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_12961_row7_col0" class="data row7 col0" >19.7692</td>
#       <td id="T_12961_row7_col1" class="data row7 col1" >589.1137</td>
#       <td id="T_12961_row7_col2" class="data row7 col2" >24.2717</td>
#       <td id="T_12961_row7_col3" class="data row7 col3" >-0.0124</td>
#       <td id="T_12961_row7_col4" class="data row7 col4" >1.0132</td>
#       <td id="T_12961_row7_col5" class="data row7 col5" >2.8128</td>
#     </tr>
#     <tr>
#       <th id="T_12961_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_12961_row8_col0" class="data row8 col0" >21.9053</td>
#       <td id="T_12961_row8_col1" class="data row8 col1" >850.3670</td>
#       <td id="T_12961_row8_col2" class="data row8 col2" >29.1611</td>
#       <td id="T_12961_row8_col3" class="data row8 col3" >-0.2433</td>
#       <td id="T_12961_row8_col4" class="data row8 col4" >0.8278</td>
#       <td id="T_12961_row8_col5" class="data row8 col5" >1.0583</td>
#     </tr>
#     <tr>
#       <th id="T_12961_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_12961_row9_col0" class="data row9 col0" >24.4989</td>
#       <td id="T_12961_row9_col1" class="data row9 col1" >980.6670</td>
#       <td id="T_12961_row9_col2" class="data row9 col2" >31.3156</td>
#       <td id="T_12961_row9_col3" class="data row9 col3" >-0.1950</td>
#       <td id="T_12961_row9_col4" class="data row9 col4" >0.9296</td>
#       <td id="T_12961_row9_col5" class="data row9 col5" >1.7119</td>
#     </tr>
#     <tr>
#       <th id="T_12961_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_12961_row10_col0" class="data row10 col0" >21.7898</td>
#       <td id="T_12961_row10_col1" class="data row10 col1" >764.3286</td>
#       <td id="T_12961_row10_col2" class="data row10 col2" >27.4779</td>
#       <td id="T_12961_row10_col3" class="data row10 col3" >-0.0670</td>
#       <td id="T_12961_row10_col4" class="data row10 col4" >0.9674</td>
#       <td id="T_12961_row10_col5" class="data row10 col5" >2.2510</td>
#     </tr>
#     <tr>
#       <th id="T_12961_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_12961_row11_col0" class="data row11 col0" >2.1637</td>
#       <td id="T_12961_row11_col1" class="data row11 col1" >168.1255</td>
#       <td id="T_12961_row11_col2" class="data row11 col2" >3.0487</td>
#       <td id="T_12961_row11_col3" class="data row11 col3" >0.0948</td>
#       <td id="T_12961_row11_col4" class="data row11 col4" >0.0941</td>
#       <td id="T_12961_row11_col5" class="data row11 col5" >0.8229</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_a609e_row10_col0, #T_a609e_row10_col1, #T_a609e_row10_col2, #T_a609e_row10_col3, #T_a609e_row10_col4, #T_a609e_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_a609e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a609e_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_a609e_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_a609e_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_a609e_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_a609e_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_a609e_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a609e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a609e_row0_col0" class="data row0 col0" >19.7586</td>
#       <td id="T_a609e_row0_col1" class="data row0 col1" >558.6942</td>
#       <td id="T_a609e_row0_col2" class="data row0 col2" >23.6367</td>
#       <td id="T_a609e_row0_col3" class="data row0 col3" >-0.0844</td>
#       <td id="T_a609e_row0_col4" class="data row0 col4" >0.9352</td>
#       <td id="T_a609e_row0_col5" class="data row0 col5" >1.7829</td>
#     </tr>
#     <tr>
#       <th id="T_a609e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a609e_row1_col0" class="data row1 col0" >20.1142</td>
#       <td id="T_a609e_row1_col1" class="data row1 col1" >639.4041</td>
#       <td id="T_a609e_row1_col2" class="data row1 col2" >25.2864</td>
#       <td id="T_a609e_row1_col3" class="data row1 col3" >0.0363</td>
#       <td id="T_a609e_row1_col4" class="data row1 col4" >0.8571</td>
#       <td id="T_a609e_row1_col5" class="data row1 col5" >1.6733</td>
#     </tr>
#     <tr>
#       <th id="T_a609e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a609e_row2_col0" class="data row2 col0" >21.1442</td>
#       <td id="T_a609e_row2_col1" class="data row2 col1" >636.8386</td>
#       <td id="T_a609e_row2_col2" class="data row2 col2" >25.2357</td>
#       <td id="T_a609e_row2_col3" class="data row2 col3" >-0.0407</td>
#       <td id="T_a609e_row2_col4" class="data row2 col4" >1.0074</td>
#       <td id="T_a609e_row2_col5" class="data row2 col5" >2.4953</td>
#     </tr>
#     <tr>
#       <th id="T_a609e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a609e_row3_col0" class="data row3 col0" >24.0883</td>
#       <td id="T_a609e_row3_col1" class="data row3 col1" >876.8267</td>
#       <td id="T_a609e_row3_col2" class="data row3 col2" >29.6113</td>
#       <td id="T_a609e_row3_col3" class="data row3 col3" >-0.0633</td>
#       <td id="T_a609e_row3_col4" class="data row3 col4" >1.0837</td>
#       <td id="T_a609e_row3_col5" class="data row3 col5" >3.9654</td>
#     </tr>
#     <tr>
#       <th id="T_a609e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a609e_row4_col0" class="data row4 col0" >24.3092</td>
#       <td id="T_a609e_row4_col1" class="data row4 col1" >943.3557</td>
#       <td id="T_a609e_row4_col2" class="data row4 col2" >30.7141</td>
#       <td id="T_a609e_row4_col3" class="data row4 col3" >-0.0368</td>
#       <td id="T_a609e_row4_col4" class="data row4 col4" >0.9867</td>
#       <td id="T_a609e_row4_col5" class="data row4 col5" >1.9006</td>
#     </tr>
#     <tr>
#       <th id="T_a609e_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_a609e_row5_col0" class="data row5 col0" >22.0053</td>
#       <td id="T_a609e_row5_col1" class="data row5 col1" >646.1457</td>
#       <td id="T_a609e_row5_col2" class="data row5 col2" >25.4194</td>
#       <td id="T_a609e_row5_col3" class="data row5 col3" >0.0092</td>
#       <td id="T_a609e_row5_col4" class="data row5 col4" >1.1074</td>
#       <td id="T_a609e_row5_col5" class="data row5 col5" >3.2898</td>
#     </tr>
#     <tr>
#       <th id="T_a609e_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_a609e_row6_col0" class="data row6 col0" >23.9871</td>
#       <td id="T_a609e_row6_col1" class="data row6 col1" >841.0356</td>
#       <td id="T_a609e_row6_col2" class="data row6 col2" >29.0006</td>
#       <td id="T_a609e_row6_col3" class="data row6 col3" >0.0276</td>
#       <td id="T_a609e_row6_col4" class="data row6 col4" >1.1384</td>
#       <td id="T_a609e_row6_col5" class="data row6 col5" >3.7362</td>
#     </tr>
#     <tr>
#       <th id="T_a609e_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_a609e_row7_col0" class="data row7 col0" >21.0863</td>
#       <td id="T_a609e_row7_col1" class="data row7 col1" >609.4983</td>
#       <td id="T_a609e_row7_col2" class="data row7 col2" >24.6880</td>
#       <td id="T_a609e_row7_col3" class="data row7 col3" >-0.0474</td>
#       <td id="T_a609e_row7_col4" class="data row7 col4" >1.0561</td>
#       <td id="T_a609e_row7_col5" class="data row7 col5" >3.1967</td>
#     </tr>
#     <tr>
#       <th id="T_a609e_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_a609e_row8_col0" class="data row8 col0" >21.5653</td>
#       <td id="T_a609e_row8_col1" class="data row8 col1" >783.1026</td>
#       <td id="T_a609e_row8_col2" class="data row8 col2" >27.9840</td>
#       <td id="T_a609e_row8_col3" class="data row8 col3" >-0.1450</td>
#       <td id="T_a609e_row8_col4" class="data row8 col4" >0.8228</td>
#       <td id="T_a609e_row8_col5" class="data row8 col5" >1.1759</td>
#     </tr>
#     <tr>
#       <th id="T_a609e_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_a609e_row9_col0" class="data row9 col0" >23.9416</td>
#       <td id="T_a609e_row9_col1" class="data row9 col1" >907.9777</td>
#       <td id="T_a609e_row9_col2" class="data row9 col2" >30.1327</td>
#       <td id="T_a609e_row9_col3" class="data row9 col3" >-0.1064</td>
#       <td id="T_a609e_row9_col4" class="data row9 col4" >0.9340</td>
#       <td id="T_a609e_row9_col5" class="data row9 col5" >1.8961</td>
#     </tr>
#     <tr>
#       <th id="T_a609e_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_a609e_row10_col0" class="data row10 col0" >22.2000</td>
#       <td id="T_a609e_row10_col1" class="data row10 col1" >744.2879</td>
#       <td id="T_a609e_row10_col2" class="data row10 col2" >27.1709</td>
#       <td id="T_a609e_row10_col3" class="data row10 col3" >-0.0451</td>
#       <td id="T_a609e_row10_col4" class="data row10 col4" >0.9929</td>
#       <td id="T_a609e_row10_col5" class="data row10 col5" >2.5112</td>
#     </tr>
#     <tr>
#       <th id="T_a609e_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_a609e_row11_col0" class="data row11 col0" >1.6537</td>
#       <td id="T_a609e_row11_col1" class="data row11 col1" >134.0324</td>
#       <td id="T_a609e_row11_col2" class="data row11 col2" >2.4558</td>
#       <td id="T_a609e_row11_col3" class="data row11 col3" >0.0553</td>
#       <td id="T_a609e_row11_col4" class="data row11 col4" >0.1005</td>
#       <td id="T_a609e_row11_col5" class="data row11 col5" >0.9197</td>
#     </tr>
#   </tbody>
# </table>
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
#clearly with an R2 value of -0.002, putting this into production is a bad idea
#there is clearly less of a relationship with selling_rating and ship_price as also evidenced by the dummy regressor
